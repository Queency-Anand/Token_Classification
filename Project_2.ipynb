# %%
import os
import pandas as pd

# Directory containing text files
directory = '/Users/qanand/Documents/DocBank/DocBank_samples/DocBank_txt'
output_folder = '/Users/qanand/Documents/DocBank/DocBank_samples/Dataframes'

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Iterate over each file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        # Read the rest of the file into a DataFrame
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath, sep='\t', skiprows=1, names=['Words', 'x0', 'y0', 'x1', 'y1', 'R', 'G', 'B', 'Font', 'Label'])
        
        # Save the DataFrame to a CSV file in the output folder
        output_filepath = os.path.join(output_folder, f"{filename.split('.')[0]}.csv")
        df.to_csv(output_filepath, index=False)

# %%
import os
import pandas as pd

# Function to convert coordinates to bounding boxes
def convert_to_bounding_box(row):
    x0, y0, x1, y1 = row['x0'], row['y0'], row['x1'], row['y1']
    return f'[{x0}, {y0}, {x1}, {y1}]'

# Directory containing CSV files
directory = "/Users/qanand/Documents/DocBank/DocBank_samples/Dataframes"

# Process each CSV file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        file_path = os.path.join(directory, filename)
        
        # Read CSV files into a DataFrame
        data = pd.read_csv(file_path)
        
        # Create 'bbox' column from coordinates
        data['bbox'] = data.apply(convert_to_bounding_box, axis=1)
        
        # Drop the original coordinate columns
        data.drop(columns=['x0', 'y0', 'x1', 'y1'], inplace=True)
        
        # Save the modified DataFrame back to the CSV file
        data.to_csv(file_path, index=False)

# %%
data
# Out:
#                 Words  R  G  B          Font      Label                  bbox
# 0                 THE  0  0  0   JPUNEJ+CMR7  paragraph  [470, 121, 497, 130]
# 1            AFFINITY  0  0  0   JPUNEJ+CMR7  paragraph  [503, 121, 567, 130]
# 2           DIMENSION  0  0  0   JPUNEJ+CMR7  paragraph  [573, 121, 649, 130]
# 3                  67  0  0  0   JPUNEJ+CMR7  paragraph  [780, 121, 793, 130]
# 4                [32]  0  0  0   MNTQTC+CMR8  reference  [206, 150, 228, 161]
# ..                ... .. .. ..           ...        ...                   ...
# 588      Mathematics.  0  0  0  CCYUVB+CMTI8  reference  [289, 855, 371, 865]
# 589  Springer-Verlag,  0  0  0   MNTQTC+CMR8  reference  [375, 855, 473, 865]
# 590               New  0  0  0   MNTQTC+CMR8  reference  [477, 855, 504, 865]
# 591             York,  0  0  0   MNTQTC+CMR8  reference  [509, 855, 541, 865]
# 592             1999.  0  0  0   MNTQTC+CMR8  reference  [546, 855, 577, 865]
#
# [593 rows x 7 columns]
